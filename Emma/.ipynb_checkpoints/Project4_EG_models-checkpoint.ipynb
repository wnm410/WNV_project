# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import roc_auc_score, auc, roc_curve
from sklearn.neighbors import KNeighborsClassifier

pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# Reading in train and test datasets, resetting the date as index

# %%
df = pd.read_csv('train_weather_per_station.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)
df.head()
# Out:
#             Num_Duplicates  WnvPresent  Year  Month  Day  CULEX ERRATICUS  \
# Date
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
#
#             CULEX PIPIENS  CULEX PIPIENS/RESTUANS  CULEX RESTUANS  \
# Date
# 2007-05-29              0                       1               0
# 2007-05-29              0                       0               1
# 2007-05-29              0                       0               1
# 2007-05-29              0                       1               0
# 2007-05-29              0                       0               1
#
#             CULEX SALINARIUS  CULEX TARSALIS  CULEX TERRITANS  Tmax  Tmin  \
# Date
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
#
#             Tavg  Depart  DewPoint  WetBulb  Cool  Sunrise  Sunset  \
# Date
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
#
#             PrecipTotal  ResultSpeed  ResultDir
# Date
# 2007-05-29          0.0          5.8         18
# 2007-05-29          0.0          5.8         18
# 2007-05-29          0.0          5.8         18
# 2007-05-29          0.0          5.8         18
# 2007-05-29          0.0          5.8         18

# %%
df.shape
# Out:
# (10506, 24)

# %%
test = pd.read_csv('test_weather_per_station.csv')
test['Date'] = pd.to_datetime(test['Date'])
test.set_index('Date', inplace = True)
test.head()
# Out:
#             Num_Duplicates  Year  Month  Day  CULEX ERRATICUS  CULEX PIPIENS  \
# Date
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              1
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              0
#
#             CULEX PIPIENS/RESTUANS  CULEX RESTUANS  CULEX SALINARIUS  \
# Date
# 2008-06-11                       1               0                 0
# 2008-06-11                       0               1                 0
# 2008-06-11                       0               0                 0
# 2008-06-11                       0               0                 1
# 2008-06-11                       0               0                 0
#
#             CULEX TARSALIS  CULEX TERRITANS  UNSPECIFIED CULEX  Tmax  Tmin  \
# Date
# 2008-06-11               0                0                  0    86    61
# 2008-06-11               0                0                  0    86    61
# 2008-06-11               0                0                  0    86    61
# 2008-06-11               0                0                  0    86    61
# 2008-06-11               0                1                  0    86    61
#
#             Tavg  Depart  DewPoint  WetBulb  Cool  Sunrise  Sunset  \
# Date
# 2008-06-11    74       7        56       64     9      416    1926
# 2008-06-11    74       7        56       64     9      416    1926
# 2008-06-11    74       7        56       64     9      416    1926
# 2008-06-11    74       7        56       64     9      416    1926
# 2008-06-11    74       7        56       64     9      416    1926
#
#             PrecipTotal  ResultSpeed  ResultDir
# Date
# 2008-06-11          0.0          8.9         18
# 2008-06-11          0.0          8.9         18
# 2008-06-11          0.0          8.9         18
# 2008-06-11          0.0          8.9         18
# 2008-06-11          0.0          8.9         18

# %%
print(f'Number of columns in the train set: {df.shape[1]}')
print(f'Number of columns in the test set: {test.shape[1]}')
# Out:
# Number of columns in the train set: 24
# Number of columns in the test set: 24

# %% [markdown]
# Since there is a column of Unspecified Species in the test data that is not in the train data, I substitute that species in the test data with the most popular species.

# %%
# checking which is the most popular species 

test[['CULEX ERRATICUS','CULEX PIPIENS','CULEX PIPIENS/RESTUANS','CULEX RESTUANS','CULEX SALINARIUS',
     'CULEX TARSALIS','CULEX TERRITANS']].sum()
# Out:
# CULEX ERRATICUS           14345
# CULEX PIPIENS             14521
# CULEX PIPIENS/RESTUANS    15359
# CULEX RESTUANS            14670
# CULEX SALINARIUS          14355
# CULEX TARSALIS            14347
# CULEX TERRITANS           14351
# dtype: int64

# %%
# assigning culex pipiens/restuans to the unspecified culex
for index, row in test.iterrows():
    if row['UNSPECIFIED CULEX'] == 1:
        test.loc[index,'CULEX PIPIENS/RESTUANS'] = 1

# check if the number of culex pipiens/restuans has actually increased
test['CULEX PIPIENS/RESTUANS'].sum()
# Out:
# 116293

# %%
# droppig the unspecified culex
test.drop('UNSPECIFIED CULEX', axis = 1, inplace = True)
test.head()
# Out:
#             Num_Duplicates  Year  Month  Day  CULEX ERRATICUS  CULEX PIPIENS  \
# Date
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              1
# 2008-06-11               1  2008      6   11                0              0
# 2008-06-11               1  2008      6   11                0              0
#
#             CULEX PIPIENS/RESTUANS  CULEX RESTUANS  CULEX SALINARIUS  \
# Date
# 2008-06-11                       1               0                 0
# 2008-06-11                       1               1                 0
# 2008-06-11                       1               0                 0
# 2008-06-11                       1               0                 1
# 2008-06-11                       1               0                 0
#
#             CULEX TARSALIS  CULEX TERRITANS  Tmax  Tmin  Tavg  Depart  \
# Date
# 2008-06-11               0                0    86    61    74       7
# 2008-06-11               0                0    86    61    74       7
# 2008-06-11               0                0    86    61    74       7
# 2008-06-11               0                0    86    61    74       7
# 2008-06-11               0                1    86    61    74       7
#
#             DewPoint  WetBulb  Cool  Sunrise  Sunset  PrecipTotal  \
# Date
# 2008-06-11        56       64     9      416    1926          0.0
# 2008-06-11        56       64     9      416    1926          0.0
# 2008-06-11        56       64     9      416    1926          0.0
# 2008-06-11        56       64     9      416    1926          0.0
# 2008-06-11        56       64     9      416    1926          0.0
#
#             ResultSpeed  ResultDir
# Date
# 2008-06-11          8.9         18
# 2008-06-11          8.9         18
# 2008-06-11          8.9         18
# 2008-06-11          8.9         18
# 2008-06-11          8.9         18

# %%
def buildLaggedFeatures(df, lag):  # df - dataframe, lag - list of numbers defining lagged values. Builds lagged weather features 
    new_dict={}
    for col_name in df:
        new_dict[col_name]=df[col_name]
        # create lagged Series
        for l in lag:
            new_dict['%s_lag%d' %(col_name,l)]=df[col_name].shift(l)
    res=pd.DataFrame(new_dict,index=df.index)
    return res

# %%
weather_feats = ['Tmax','Tmin','Tavg','Depart','DewPoint','WetBulb','Cool','PrecipTotal','ResultSpeed','ResultDir']
lagged_train = buildLaggedFeatures(df[weather_feats], [1,3,5,7])
lagged_test = buildLaggedFeatures(test[weather_feats], [1,3,5,7])
lagged_train.head()
# Out:
#             Tmax  Tmax_lag1  Tmax_lag3  Tmax_lag5  Tmax_lag7  Tmin  Tmin_lag1  \
# Date
# 2007-05-29    88        NaN        NaN        NaN        NaN    60        NaN
# 2007-05-29    88       88.0        NaN        NaN        NaN    60       60.0
# 2007-05-29    88       88.0        NaN        NaN        NaN    60       60.0
# 2007-05-29    88       88.0       88.0        NaN        NaN    60       60.0
# 2007-05-29    88       88.0       88.0        NaN        NaN    60       60.0
#
#             Tmin_lag3  Tmin_lag5  Tmin_lag7  Tavg  Tavg_lag1  Tavg_lag3  \
# Date
# 2007-05-29        NaN        NaN        NaN    74        NaN        NaN
# 2007-05-29        NaN        NaN        NaN    74       74.0        NaN
# 2007-05-29        NaN        NaN        NaN    74       74.0        NaN
# 2007-05-29       60.0        NaN        NaN    74       74.0       74.0
# 2007-05-29       60.0        NaN        NaN    74       74.0       74.0
#
#             Tavg_lag5  Tavg_lag7  Depart  Depart_lag1  Depart_lag3  \
# Date
# 2007-05-29        NaN        NaN      10          NaN          NaN
# 2007-05-29        NaN        NaN      10         10.0          NaN
# 2007-05-29        NaN        NaN      10         10.0          NaN
# 2007-05-29        NaN        NaN      10         10.0         10.0
# 2007-05-29        NaN        NaN      10         10.0         10.0
#
#             Depart_lag5  Depart_lag7  DewPoint  DewPoint_lag1  DewPoint_lag3  \
# Date
# 2007-05-29          NaN          NaN        58            NaN            NaN
# 2007-05-29          NaN          NaN        58           58.0            NaN
# 2007-05-29          NaN          NaN        58           58.0            NaN
# 2007-05-29          NaN          NaN        58           58.0           58.0
# 2007-05-29          NaN          NaN        58           58.0           58.0
#
#             DewPoint_lag5  DewPoint_lag7  WetBulb  WetBulb_lag1  WetBulb_lag3  \
# Date
# 2007-05-29            NaN            NaN       65           NaN           NaN
# 2007-05-29            NaN            NaN       65          65.0           NaN
# 2007-05-29            NaN            NaN       65          65.0           NaN
# 2007-05-29            NaN            NaN       65          65.0          65.0
# 2007-05-29            NaN            NaN       65          65.0          65.0
#
#             WetBulb_lag5  WetBulb_lag7  Cool  Cool_lag1  Cool_lag3  Cool_lag5  \
# Date
# 2007-05-29           NaN           NaN     9        NaN        NaN        NaN
# 2007-05-29           NaN           NaN     9        9.0        NaN        NaN
# 2007-05-29           NaN           NaN     9        9.0        NaN        NaN
# 2007-05-29           NaN           NaN     9        9.0        9.0        NaN
# 2007-05-29           NaN           NaN     9        9.0        9.0        NaN
#
#             Cool_lag7  PrecipTotal  PrecipTotal_lag1  PrecipTotal_lag3  \
# Date
# 2007-05-29        NaN          0.0               NaN               NaN
# 2007-05-29        NaN          0.0               0.0               NaN
# 2007-05-29        NaN          0.0               0.0               NaN
# 2007-05-29        NaN          0.0               0.0               0.0
# 2007-05-29        NaN          0.0               0.0               0.0
#
#             PrecipTotal_lag5  PrecipTotal_lag7  ResultSpeed  ResultSpeed_lag1  \
# Date
# 2007-05-29               NaN               NaN          5.8               NaN
# 2007-05-29               NaN               NaN          5.8               5.8
# 2007-05-29               NaN               NaN          5.8               5.8
# 2007-05-29               NaN               NaN          5.8               5.8
# 2007-05-29               NaN               NaN          5.8               5.8
#
#             ResultSpeed_lag3  ResultSpeed_lag5  ResultSpeed_lag7  ResultDir  \
# Date
# 2007-05-29               NaN               NaN               NaN         18
# 2007-05-29               NaN               NaN               NaN         18
# 2007-05-29               NaN               NaN               NaN         18
# 2007-05-29               5.8               NaN               NaN         18
# 2007-05-29               5.8               NaN               NaN         18
#
#             ResultDir_lag1  ResultDir_lag3  ResultDir_lag5  ResultDir_lag7
# Date
# 2007-05-29             NaN             NaN             NaN             NaN
# 2007-05-29            18.0             NaN             NaN             NaN
# 2007-05-29            18.0             NaN             NaN             NaN
# 2007-05-29            18.0            18.0             NaN             NaN
# 2007-05-29            18.0            18.0             NaN             NaN

# %%
df = pd.concat([df,lagged_train], axis = 1)
test = pd.concat([test,lagged_test], axis = 1)

# %%
df = df.fillna(method = 'bfill')
test = test.fillna(method = 'bfill')

# %%
df.shape
# Out:
# (10506, 74)

# %%
test.shape
# Out:
# (116293, 73)

# %%
df.head()
# Out:
#             Num_Duplicates  WnvPresent  Year  Month  Day  CULEX ERRATICUS  \
# Date
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
# 2007-05-29               1           0  2007      5   29                0
#
#             CULEX PIPIENS  CULEX PIPIENS/RESTUANS  CULEX RESTUANS  \
# Date
# 2007-05-29              0                       1               0
# 2007-05-29              0                       0               1
# 2007-05-29              0                       0               1
# 2007-05-29              0                       1               0
# 2007-05-29              0                       0               1
#
#             CULEX SALINARIUS  CULEX TARSALIS  CULEX TERRITANS  Tmax  Tmin  \
# Date
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
# 2007-05-29                 0               0                0    88    60
#
#             Tavg  Depart  DewPoint  WetBulb  Cool  Sunrise  Sunset  \
# Date
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
# 2007-05-29    74      10        58       65     9      421    1917
#
#             PrecipTotal  ResultSpeed  ResultDir  Tmax  Tmax_lag1  Tmax_lag3  \
# Date
# 2007-05-29          0.0          5.8         18    88       88.0       88.0
# 2007-05-29          0.0          5.8         18    88       88.0       88.0
# 2007-05-29          0.0          5.8         18    88       88.0       88.0
# 2007-05-29          0.0          5.8         18    88       88.0       88.0
# 2007-05-29          0.0          5.8         18    88       88.0       88.0
#
#             Tmax_lag5  Tmax_lag7  Tmin  Tmin_lag1  Tmin_lag3  Tmin_lag5  \
# Date
# 2007-05-29       88.0       88.0    60       60.0       60.0       60.0
# 2007-05-29       88.0       88.0    60       60.0       60.0       60.0
# 2007-05-29       88.0       88.0    60       60.0       60.0       60.0
# 2007-05-29       88.0       88.0    60       60.0       60.0       60.0
# 2007-05-29       88.0       88.0    60       60.0       60.0       60.0
#
#             Tmin_lag7  Tavg  Tavg_lag1  Tavg_lag3  Tavg_lag5  Tavg_lag7  \
# Date
# 2007-05-29       60.0    74       74.0       74.0       74.0       74.0
# 2007-05-29       60.0    74       74.0       74.0       74.0       74.0
# 2007-05-29       60.0    74       74.0       74.0       74.0       74.0
# 2007-05-29       60.0    74       74.0       74.0       74.0       74.0
# 2007-05-29       60.0    74       74.0       74.0       74.0       74.0
#
#             Depart  Depart_lag1  Depart_lag3  Depart_lag5  Depart_lag7  \
# Date
# 2007-05-29      10         10.0         10.0         10.0         10.0
# 2007-05-29      10         10.0         10.0         10.0         10.0
# 2007-05-29      10         10.0         10.0         10.0         10.0
# 2007-05-29      10         10.0         10.0         10.0         10.0
# 2007-05-29      10         10.0         10.0         10.0         10.0
#
#             DewPoint  DewPoint_lag1  DewPoint_lag3  DewPoint_lag5  \
# Date
# 2007-05-29        58           58.0           58.0           58.0
# 2007-05-29        58           58.0           58.0           58.0
# 2007-05-29        58           58.0           58.0           58.0
# 2007-05-29        58           58.0           58.0           58.0
# 2007-05-29        58           58.0           58.0           58.0
#
#             DewPoint_lag7  WetBulb  WetBulb_lag1  WetBulb_lag3  WetBulb_lag5  \
# Date
# 2007-05-29           58.0       65          65.0          65.0          65.0
# 2007-05-29           58.0       65          65.0          65.0          65.0
# 2007-05-29           58.0       65          65.0          65.0          65.0
# 2007-05-29           58.0       65          65.0          65.0          65.0
# 2007-05-29           58.0       65          65.0          65.0          65.0
#
#             WetBulb_lag7  Cool  Cool_lag1  Cool_lag3  Cool_lag5  Cool_lag7  \
# Date
# 2007-05-29          65.0     9        9.0        9.0        9.0        9.0
# 2007-05-29          65.0     9        9.0        9.0        9.0        9.0
# 2007-05-29          65.0     9        9.0        9.0        9.0        9.0
# 2007-05-29          65.0     9        9.0        9.0        9.0        9.0
# 2007-05-29          65.0     9        9.0        9.0        9.0        9.0
#
#             PrecipTotal  PrecipTotal_lag1  PrecipTotal_lag3  PrecipTotal_lag5  \
# Date
# 2007-05-29          0.0               0.0               0.0               0.0
# 2007-05-29          0.0               0.0               0.0               0.0
# 2007-05-29          0.0               0.0               0.0               0.0
# 2007-05-29          0.0               0.0               0.0               0.0
# 2007-05-29          0.0               0.0               0.0               0.0
#
#             PrecipTotal_lag7  ResultSpeed  ResultSpeed_lag1  ResultSpeed_lag3  \
# Date
# 2007-05-29               0.0          5.8               5.8               5.8
# 2007-05-29               0.0          5.8               5.8               5.8
# 2007-05-29               0.0          5.8               5.8               5.8
# 2007-05-29               0.0          5.8               5.8               5.8
# 2007-05-29               0.0          5.8               5.8               5.8
#
#             ResultSpeed_lag5  ResultSpeed_lag7  ResultDir  ResultDir_lag1  \
# Date
# 2007-05-29               5.8               5.8         18            18.0
# 2007-05-29               5.8               5.8         18            18.0
# 2007-05-29               5.8               5.8         18            18.0
# 2007-05-29               5.8               5.8         18            18.0
# 2007-05-29               5.8               5.8         18            18.0
#
#             ResultDir_lag3  ResultDir_lag5  ResultDir_lag7
# Date
# 2007-05-29            18.0            18.0            18.0
# 2007-05-29            18.0            18.0            18.0
# 2007-05-29            18.0            18.0            18.0
# 2007-05-29            18.0            18.0            18.0
# 2007-05-29            18.0            18.0            18.0

# %% [markdown]
# # Defining X and y, and train/test split

# %% [raw]
# wnv_pres = df[df['WnvPresent']==1]
# train_bootstrapped = wnv_pres.sample(n=8000, replace=True)
# df = pd.merge(df, train_bootstrapped, how="outer")

# %%
wnv_pres = df[df['WnvPresent']==1]
train_bootstrapped = wnv_pres.sample(n=8000, replace=True)
train_bootstrapped.shape
# Out:
# (8000, 74)

# %%
df = pd.concat([df,train_bootstrapped])

# %%
# features = [feat for feat in df.columns if feat != "WnvPresent"]

X = df.drop(columns = ['WnvPresent'])
y = df['WnvPresent']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 17, stratify = y)

# %%
X_train.shape
# Out:
# (14804, 73)

# %% [markdown]
# Feature engineering.

# %% [raw]
# X['DewTavg'] = X['DewPoint']*X['Tavg']
# X['Tmaxavg'] = X['Tavg']*X['Tmax']
# X['Tmax^2'] = X['Tmax']**2
# X['Dew^2'] = X['DewPoint']**2
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 17, stratify = y)

# %% [raw]
# test['DewTavg'] = test['DewPoint']*test['Tavg']
# test['Tmaxavg'] = test['Tavg']*test['Tmax']
# test['Tmax^2'] = test['Tmax']**2
# test['Dew^2'] = test['DewPoint']**2

# %% [markdown]
# Tried to generate polinomial features but did not increase the score.

# %% [raw]
# from sklearn.preprocessing import PolynomialFeatures
#
# poly = PolynomialFeatures(2)
# X = pd.DataFrame(poly.fit_transform(X))
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 17)

# %% [markdown]
# # KNN model

# %%
k = np.arange(3,30,2)
parameters = {'n_neighbors': k,
              'p': [1,2] }
knn = KNeighborsClassifier()
clf = GridSearchCV(knn,parameters,cv=10)
clf.fit(X_train, y_train)

# %%
clf.best_params_

# %%
y_pred = clf.predict(X_test)
auc_knn = roc_auc_score(y_test, y_pred)
auc_knn

# %% [markdown]
# # Logistic Regression model

# %% [markdown]
# This sucks, but whatever.

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
auc_logreg = roc_auc_score(y_test, y_pred)
auc_logreg

# %% [markdown]
# # Random Forest w/ Grid Search

# %%
params = {'n_estimators': [15],
          'max_depth': [60]}
rfc = RandomForestClassifier() 
rfcl = GridSearchCV(rfc,params,cv=10)
rfcl.fit(X_train, y_train)
rfcl.best_params_
# Out:
# {'max_depth': 60, 'n_estimators': 15}

# %%
y_pred = rfcl.predict(X_test)
auc_rfcl = roc_auc_score(y_test, y_pred)
auc_rfcl
# Out:
# 0.9398523474732001

# %%
probs = rfcl.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,8))
plt.title('Receiver Operating Characteristic', ha = 'left', x = 0, fontsize = 20)
plt.plot(fpr, tpr, c = 'mediumslateblue', label = 'AUC = %0.2f' % roc_auc, lw = 4)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--', lw = 4)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate', fontsize = 18)
plt.xlabel('False Positive Rate', fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18);

# %% [markdown]
# # --

# %%
sub_pred = rfcl.predict(test)
Id = list(range(1,len(sub_pred)+1))

# %%
sub_pred.shape
# Out:
# (116293,)

# %%
sub = pd.DataFrame(Id, columns = ['Id'])
sub['WnvPresent'] = sub_pred
sub['WnvPresent'] = sub['WnvPresent'].astype(int)
sub.head()
# Out:
#    Id  WnvPresent
# 0   1           0
# 1   2           0
# 2   3           0
# 3   4           0
# 4   5           0

# %%
sub.to_csv('Sept19_sub.csv', index = False)
